# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = np.linspace(0, 10, 100)
gamma = 1
y = np.exp(-gamma*x)
z = np.exp(-2*gamma*x)

plt.figure()
plt.plot(x, y)
plt.plot(x, z)
plt.xlabel('$x$')
plt.ylabel('$\exp(x)$')

plt.show()
